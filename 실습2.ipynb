# %% [markdown]
# <a href="https://colab.research.google.com/github/kjs444642-alt/dl.practice1/blob/main/%EC%8B%A4%EC%8A%B52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-813617c4-80f4-495c-9cb0-af930c1cf88d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-813617c4-80f4-495c-9cb0-af930c1cf88d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile('/content/archive.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
import os

os.listdir('/content/')
# Out:
# ['.config', 'archive.zip', 'Negative', 'Positive', 'sample_data']

# %%
base_dir = '/content/Concrete Crack Images for Classification'

positive_dir = os.path.join(base_dir, 'Positive')
negative_dir = os.path.join(base_dir, 'Negative')

# %%
import os

positive_dir = '/content/Positive'
negative_dir = '/content/Negative'

print("Positive:", len(os.listdir(positive_dir)))
print("Negative:", len(os.listdir(negative_dir)))
print("Total:", len(os.listdir(positive_dir)) + len(os.listdir(negative_dir)))
# Out:
# Positive: 20000
# Negative: 20000
# Total: 40000

# %%
import matplotlib.pyplot as plt
import random
from PIL import Image

sample_pos = random.choice(os.listdir(positive_dir))
sample_neg = random.choice(os.listdir(negative_dir))

img1 = Image.open(os.path.join(positive_dir, sample_pos))
img2 = Image.open(os.path.join(negative_dir, sample_neg))

plt.figure(figsize=(8,4))

plt.subplot(1,2,1)
plt.imshow(img1)
plt.title("Positive")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(img2)
plt.title("Negative")
plt.axis('off')

plt.show()

# %% [markdown]
# ## 데이터셋 설명
#
# 본 데이터셋은 콘크리트 표면 이미지로 구성되어 있으며, 균열 여부에 따라 Positive와 Negative로 분류되어 있다.
#
# - Positive: 약 20,000장
# - Negative: 약 20,000장
# - Total: 약 40,000장

# %%
from sklearn import datasets
import pandas as pd

breast_cancer_data = datasets.load_breast_cancer()

df_2 = pd.DataFrame(
    data=breast_cancer_data.data,
    columns=breast_cancer_data.feature_names
)

df_2['target'] = breast_cancer_data.target

df_2
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
from sklearn import datasets
import pandas as pd

# %%
raw = datasets.load_breast_cancer()
df = pd.DataFrame(raw.data, columns=raw.feature_names)

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
import seaborn as sns

# %%
colormap = plt.cm.gist_heat   # 그래프 색상 구성
plt.figure(figsize=(12,12))   # 그래프 크기

# %%
sns.heatmap(df.corr(),linewidths=0.1,vmax=0.5, cmap=colormap, linecolor='white', annot=True)
plt.show()

# %% [markdown]
# mean radius와 worst concavity가 강한 상관관계를 가진다.
